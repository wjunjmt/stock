# %%
import tushare as ts
import datetime
import pandas as pd

# %%
stock_info=ts.get_stock_basics()

# %%
def all_stocks():
    for stock_id in stock_info.index:
        if break_high(stock_id,60):
            print 'High price on'
            print stock_id,
            print stock_info.ix[stock_id]['name'].decode('utf-8')
            print stock_info.ix[stock_id]['pe']
            #df=pd.DataFrame([stock_id,stock_info.ix[stock_id]['name'].decode('utf-8').encode('gb2312')])

# %%
def break_high(stock_id,days):
    end_day=datetime.date(datetime.date.today().year,datetime.date.today().month,datetime.date.today().day)
    days=days*7/5
    start_day=end_day-datetime.timedelta(days)
    start_day=start_day.strftime("%Y-%m-%d")
    end_day=end_day.strftime("%Y-%m-%d")
    df=ts.get_h_data(stock_id,start=start_day,end=end_day)
    period_high=df['high'].max()
    today_high=df.iloc[0]['high']
    if today_high>=period_high:
        return True
    else:
        return False

# %%
stock_info.dtypes
# Out:
# name                 object
# industry             object
# area                 object
# pe                  float64
# outstanding         float64
# totals              float64
# totalAssets         float64
# liquidAssets        float64
# fixedAssets         float64
# reserved            float64
# reservedPerShare    float64
# esp                 float64
# bvps                float64
# pb                  float64
# timeToMarket          int64
# undp                float64
# perundp             float64
# rev                 float64
# profit              float64
# gpr                 float64
# npr                 float64
# holders               int64
# dtype: object

# %%
pd.DataFrame(all_stocks()).to_csv('b.csv')
# Out:
# [Getting data:]#High price on
# 603063 N禾望
# 32.68
# [Getting data:]
# /Users/WuJun/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
# #High price on
# 603730 N岱美
# 26.54
# [Getting data:]#High price on
# 300678 N中科
# 0.0
# [Getting data:]#High price on
# 601919 中远海控
# 65.05
# [Getting data:]#High price on
# 601015 陕西黑猫
# 68.24
# [Getting data:]#[Getting data:]#High price on
# 600740 山西焦化
# 125.96
# [Getting data:]#High price on
# 603676 卫信康
# 67.51
# [Getting data:]#High price on
# 002386 天原集团
# 126.62
# [Getting data:]#[Getting data:]#High price on
# 002753 永东股份
# 37.87
# [Getting data:]#[Getting data:]#High price on
# 601011 宝泰隆
# 148.29
# [Getting data:]#High price on
# 300175 朗源股份
# 19.42
# [Getting data:]#High price on
# 600516 方大炭素
# 187.89
# [Getting data:]#High price on
# 600779 水井坊
# 70.62
# [Getting data:]#High price on
# 300035 中科电气
# 111.75
# [Getting data:]#High price on
# 300676 华大基因
# 53.97
# [Getting data:]#High price on
# 002888 惠威科技
# 68.94
# [Getting data:]#High price on
# 300681 英搏尔
# 27.81
# [Getting data:]#[Getting data:]#High price on
# 002507 涪陵榨菜
# 38.2
# [Getting data:]#High price on
# 603612 索通发展
# 13.33
# [Getting data:]#High price on
# 000009 中国宝安
# 148.49
# [Getting data:]#High price on
# 600117 西宁特钢
# 188.69
# [Getting data:]#High price on
# 300680 隆盛科技
# 42.89
# [Getting data:]#[Getting data:]#High price on
# 000835 长城动漫
# 39.41
# [Getting data:]#High price on
# 300675 建科院
# 228.46
# [Getting data:]#[Getting data:]#High price on
# 601619 嘉泽新能
# 53.67
# [Getting data:]#[Getting data:]#High price on
# 000596 古井贡酒
# 16.46
# [Getting data:]#High price on
# 002015 霞客环保
# 0.0
# [Getting data:]#High price on
# 002365 永安药业
# 61.4
# [Getting data:]#[Getting data:]#High price on
# 002460 赣锋锂业
# 87.47
# [Getting data:]#High price on
# 000799 酒鬼酒
# 51.11
# [Getting data:]#High price on
# 000970 中科三环
# 63.64
# [Getting data:]#High price on
# 603589 口子窖
# 19.76
# [Getting data:]#[Getting data:]#High price on
# 000709 河钢股份
# 20.97
# [Getting data:]#High price on
# 600392 盛和资源
# 192.56
# [Getting data:]#[Getting data:]#High price on
# 600111 北方稀土
# 206.39
# [Getting data:]#High price on
# 600563 法拉电子
# 37.46
# [Getting data:]#High price on
# 002161 远 望 谷
# 0.0
# [Getting data:]#High price on
# 600101 明星电力
# 39.28
# [Getting data:]#High price on
# 300601 康泰生物
# 92.14
# [Getting data:]#[Getting data:]#[Getting data:]#High price on
# 600702 沱牌舍得
# 61.7
# [Getting data:]#[Getting data:]#High price on
# 002182 云海金属
# 35.09
# [Getting data:]#[Getting data:]#High price on
# 600338 西藏珠峰
# 26.97
# [Getting data:]#[Getting data:]#[Getting data:]#High price on
# 000989 九 芝 堂
# 32.31
# [Getting data:]#[Getting data:]#[Getting data:]#[Getting data:]#[Getting data:]#High price on
# 000560 昆百大Ａ
# 215.81
# [Getting data:]#[Getting data:]#[Getting data:]#[Getting data:]#[Getting data:]#High price on
# 002068 黑猫股份
# 40.95
# [Getting data:]#[Getting data:]#High price on
# 000546 金圆股份
# 0.0
# [Getting data:]#High price on
# 600330 天通股份
# 37.71
# [Getting data:]#[Getting data:]#High price on
# 300418 昆仑万维
# 40.49
# [Getting data:]#[Getting data:]#High price on
# 600586 金晶科技
# 43.35
# [Getting data:]#[Getting data:]#[Getting data:]#[Getting data:]#High price on
# 002449 国星光电
# 40.49
# [Getting data:]#[Getting data:]#High price on
# 601012 隆基股份
# 23.83
# [Getting data:]#[Getting data:]#High price on
# 603369 今世缘
# 12.22
# [Getting data:]#High price on
# 600331 宏达股份
# 64.89
# [Getting data:]#[Getting data:]#High price on
# 300069 金利华电
# 159.2
# [Getting data:]#[Getting data:]#[Getting data:]#[Getting data:]#[Getting data:]#High price on
# 002348 高乐股份
# 187.36
# [Getting data:]#[Getting data:]#[Getting data:]#
